# %%
from ML.HelperFunctionsText import TextProcessingClass

# %%
with open("../tests/audi.txt", "r") as f:
    audi = f.read()

# %%
audi
# Out:
# 'The origins of the company are complex, going back to the early 20th century and the initial enterprises (Horch and the Audiwerke) founded by engineer August Horch; and two other manufacturers (DKW and Wanderer), leading to the foundation of Auto Union in 1932. The modern era of Audi essentially began in the 1960s when Auto Union was acquired by Volkswagen from Daimler-Benz.[10] After relaunching the Audi brand with the 1965 introduction of the Audi F103 series, Volkswagen merged Auto Union with NSU Motorenwerke in 1969, thus creating the present day form of the company.'

# %% [markdown]
# ## Create an object of the TextProcessingClass class

# %%
obj =TextProcessingClass(audi)
# Out:
# Initializing spacy model, this can take some time.

# %% [markdown]
# ### tokens

# %%
obj.tokenize()
# Out:
# {'text': 'The origins of the company are complex, going back to the early 20th century and the initial enterprises (Horch and the Audiwerke) founded by engineer August Horch; and two other manufacturers (DKW and Wanderer), leading to the foundation of Auto Union in 1932. The modern era of Audi essentially began in the 1960s when Auto Union was acquired by Volkswagen from Daimler-Benz.[10] After relaunching the Audi brand with the 1965 introduction of the Audi F103 series, Volkswagen merged Auto Union with NSU Motorenwerke in 1969, thus creating the present day form of the company.',
#  'tokens': ['The',
#   'origins',
#   'of',
#   'the',
#   'company',
#   'are',
#   'complex',
#   ',',
#   'going',
#   'back',
#   'to',
#   'the',
#   'early',
#   '20th',
#   'century',
#   'and',
#   'the',
#   'initial',
#   'enterprises',
#   '(',
#   'Horch',
#   'and',
#   'the',
#   'Audiwerke',
#   ')',
#   'founded',
#   'by',
#   'engineer',
#   'August',
#   'Horch',
#   ';',
#   'and',
# ...

# %% [markdown]
# ### Parts of speech tags

# %%
obj.get_pos_tags()
# Out:
# {'text': 'The origins of the company are complex, going back to the early 20th century and the initial enterprises (Horch and the Audiwerke) founded by engineer August Horch; and two other manufacturers (DKW and Wanderer), leading to the foundation of Auto Union in 1932. The modern era of Audi essentially began in the 1960s when Auto Union was acquired by Volkswagen from Daimler-Benz.[10] After relaunching the Audi brand with the 1965 introduction of the Audi F103 series, Volkswagen merged Auto Union with NSU Motorenwerke in 1969, thus creating the present day form of the company.',
#  'pos_dict': {'The': 'DET',
#   'origins': 'NOUN',
#   'of': 'ADP',
#   'the': 'DET',
#   'company': 'NOUN',
#   'are': 'AUX',
#   'complex': 'ADJ',
#   ',': 'PUNCT',
#   'going': 'VERB',
#   'back': 'ADV',
#   'to': 'ADP',
#   'early': 'ADJ',
#   '20th': 'ADJ',
#   'century': 'NOUN',
#   'and': 'CCONJ',
#   'initial': 'ADJ',
#   'enterprises': 'NOUN',
#   '(': 'PUNCT',
#   'Horch': 'PROPN',
# ...

# %% [markdown]
# ### Named entities

# %%
obj.get_ner_tags()
# Out:
# {'text': 'The origins of the company are complex, going back to the early 20th century and the initial enterprises (Horch and the Audiwerke) founded by engineer August Horch; and two other manufacturers (DKW and Wanderer), leading to the foundation of Auto Union in 1932. The modern era of Audi essentially began in the 1960s when Auto Union was acquired by Volkswagen from Daimler-Benz.[10] After relaunching the Audi brand with the 1965 introduction of the Audi F103 series, Volkswagen merged Auto Union with NSU Motorenwerke in 1969, thus creating the present day form of the company.',
#  'ner_dict': {'the early 20th century': 'DATE',
#   'Horch': 'PERSON',
#   'Audiwerke': 'ORG',
#   'August': 'DATE',
#   'two': 'CARDINAL',
#   'DKW': 'ORG',
#   'Wanderer': 'ORG',
#   'Auto Union': 'ORG',
#   '1932': 'DATE',
#   'The modern era': 'DATE',
#   'Audi': 'PRODUCT',
#   'the 1960s': 'DATE',
#   'Volkswagen': 'ORG',
#   'Daimler-Benz.[10]': 'ORG',
#   '1965': 'DATE',
# ...

# %% [markdown]
# ### Word vectors

# %%
obj.get_word_vector()
# Out:
# doc_text_vector : {'the early 20th century': '[ 1.77772507e-01  1.58687979e-01  1.60269260e-01  4.40687537e-02\n -2.71833748e-01  9.51327980e-02 -1.43174976e-02  2.12285489e-01\n  7.36122504e-02  2.54535007e+00 -7.23790079e-02 -3.93074989e-01\n  1.67815760e-01  2.75242507e-01  2.00488999e-01  1.86257496e-01\n -7.00300038e-02  8.65375042e-01  3.33595008e-01 -4.42067504e-01\n  6.61624968e-02 -2.35602006e-01  1.30334981e-02  1.21443003e-01\n  1.84187502e-01 -5.86749986e-02  1.06674999e-01  1.96329758e-01\n -3.70862484e-01  3.52062523e-01  1.07493073e-01  8.84400010e-02\n  3.30734998e-01 -1.36590242e-01  2.99842507e-01  1.72884002e-01\n  4.06922475e-02  8.89220983e-02 -1.82244480e-02  2.40572497e-01\n  6.57242462e-02  3.48837525e-01 -2.35841259e-01  1.21174000e-01\n  3.29528272e-01 -2.54274998e-02 -8.93649980e-02 -6.91244006e-02\n -4.24637496e-02  4.07642484e-01  1.24307498e-01  9.63989943e-02\n -8.92678946e-02  2.85484999e-01  1.70611754e-01 -1.95610255e-01\n  1.30588740e-01  1.20459750
# ...
